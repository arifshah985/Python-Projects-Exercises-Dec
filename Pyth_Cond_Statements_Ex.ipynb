# %% [markdown]
# Conditional Statements(if,elif,else)

# %%
## if Statement

age = 17

if age>18:
  print("you can vote in elections")

elif age==17:
  print("you can vote in next elections")

else:
  print("you are under age")
# Out:
# you can vote in next elections

# %% [markdown]
# Nested Conditional statement

# %%
num = -1

if num >=0:
  print(num,"is positove")
  if num%2==0:
    print("this is Even")
  else:
    print("this is Odd")

else:
  print(num," is a negative number")
# Out:
# -1  is a negative number

# %% [markdown]
# Exercise Nested IF

# %%
## Determine if a year is leap year using nested If conditional statement

year = int(input("Enter year"))

if year%4==0:
  if year%100==0:
    if year%400==0:
       print(year," is a Leap year")
    else:
      print(year," is not a Leap year")
  else:
    print(year," is a Leap year")
else:
  print(year,"is not a leap year")
# Out:
# Enter year2024
# 2024  is a Leap year

# %% [markdown]
# Simple Calculator program

# %%
from ast import operator
num1=float(input("Enter first number"))
num2=float(input("Enter second number"))
operator=input("Enter operator")

if operator=="+":
  result=num1+num2
elif operator=="-":
  result=num1-num2
elif operator=="*":
  result=num1*num2
elif operator=="/":
  if num2 !=0:
    result=num1/num2
  else:
    print("Error: Division by Zero")
else:
  result="Invalid operator"

print("Result:",result)
# Out:
# Enter first number10
# Enter second number5
# Enter operator/
# Result: 2.0

# %%
## Determione the ticket price based on age and whether the person is a student.

age = int(input("Enter age"))
is_stiudent = input("Are you a student? (yes/no)").lower()

ticket_price=0

if age < 7:
  ticket_price="Free Ticket"
elif age <= 12:
  ticket_price=10
elif age <= 25:
  if is_stiudent=="yes":
    ticket_price=15
  else:
    ticket_price=20
else:
  ticket_price=25


print("Ticket Price:",ticket_price)
# Out:
# Enter age20
# Are you a student? (yes/no)no
# Ticket Price: 20

# %% [markdown]
# ##1. Determine if a year is leap year using nested If conditional statement
# ##2. Determine the ticket price based on age and whether the person is a student.
# ##3. Simple Calculator program

# %%
##1. Determine if a year is leap year using nested If conditional statement

year = int(input("Enter Year"))

if year % 4 == 0:
   if year % 100 == 0:
      if year % 400 == 0:
        print(year,"  is a leap year")
      else:
        print(year," is not a leap year")
   else:
    print(year," is a leap year")
else:
  print(year," is not a leap year")
# Out:
# Enter Year2026
# 2026  is not a leap year kamal

# %%
##2. Determine the ticket price based on age and whether the person is a student.

age = int(input("Enter age"))


if age < 7:
  ticket_price="Free Ticket"

elif age <=12:
  ticket_price=10

elif age <= 25:
  is_student = input("Are you a student (yes/no)").lower()
  if is_student=="yes":
    ticket_price=15
  else:
    ticket_price=20

else:
  ticket_price=20

print("ticket price is :",ticket_price)
# Out:
# Enter age5
# ticket price is : Free Ticket

# %%
##3. Simple Calculator program

num1 = float(input("Enter first number"))
num2 = float(input("Enter second numbert"))
operator = input("Enter operator '+','-','*','/'")

if operator == '+':
  result = num1 + num2
elif operator == '-':
  result = num1 - num2
elif operator == '*':
  result = num1 * num2
elif operator == '/':
  if num2 != 0:
    result = num1 / num2
  else:
    print("Error: Division by Zero")
else:
  result = "Invalid operator"

print("Result:",result)
# Out:
# Enter first number25
# Enter second numbert5
# Enter operator '+','-','*','/'/
# Result: 5.0
