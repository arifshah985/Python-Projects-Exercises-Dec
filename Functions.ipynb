# %% [markdown]
# ## Basic Math Quiz Game.
#
# ##Develop a Basic Math Quiz Game:
#  Create an interactive 'Basic Math Quiz Game' that challenges users with randomly generated arithmetic questions (addition, subtraction, multiplication), evaluates their answers, tracks their score, and provides performance feedback upon completion. The game should be engaging and help users practice fundamental math skills.
#
#  ##Solution:
#
# Design the Game Flow (Question): How would you design the overall structure of a simple math quiz game? Consider: How many questions will there be? How will the game start and end? How will you keep track of the player's score throughout the game?
#
# Generate Math Questions (Question): To create a single math question, how would you generate two random numbers? How can you randomly select an arithmetic operator (like +, -, *)? Once you have the numbers and operator, how will you calculate the correct answer for that specific question?
#
# Handle User Input and Check Answer (Question): What programming constructs would you use to get the user's answer? Once you have their input, how will you compare it to the correct answer? What kind of feedback (e.g., 'Correct!' or 'Wrong!') should the game provide to the user based on their answer?
#
# Implement Scoring and Game Loop (Question): How will you implement a system to keep a running score? To repeat the process of generating a question, getting an answer, and checking it for a set number of rounds, what type of loop structure would you use?
#
# Display Final Results (Question): After all questions have been answered, how will you display the player's final score? What kind of conditional messages would you show them based on their performance (e.g., 'Great job!' for a high score, or 'Keep practicing!' for a lower score)?
#
# Final Task: Reflect on the complete logic you've designed for the Math Quiz Game. Which programming concepts (like functions, loops, conditionals, random numbers, input/output) were essential, and how did each contribute to building the game?

# %%
import random

# Step 1: Define the math question function.

def generate_question():
  num1=random.randint(1,10)
  num2=random.randint(1,10)
  operator=random.choice(['-','+','*'])

  if operator=='-':
    answer=num1-num2
  elif operator=='+':
    answer=num1+num2
  else:
    answer=num1*num2


  # generate_question()

  return f"{num1} {operator} {num2}", answer


# generate_question()

# Step 2: Main Quiz game function
def math_quiz():
  score=0
  rounds=5

  print("\n---Welcome to this Math quiz Game!")
  print("\n you will be presented a math problem and you need to provide correct answer.")


  for i in range(rounds):
    question,correct_answer=generate_question()

    print(f"\n Question{i+1}: {question}")
    user_answer=int(input("your answer:"))

    if user_answer==correct_answer:
      print("Correct answer!")
      score+=1
    else:
      print(f"Wrong! The Correct Answer is: {correct_answer}")


  print(f"\n---Game Over!---")
  print(f"your final score is: {score}/{rounds}")

  if score==rounds:
    print("Congratulations! You got all the questions correct.")
  elif score >= rounds//2:
    print("Good job! You did well.")
  else:
    print("Keep practicing! You can do better next time.")


# Step 3: Run the Game
math_quiz()
# Out:
# ---Welcome to this Math quiz Game!
#
#  you will be presented a math problem and you need to provide correct answer.
#
#  Question1: 8 + 1
# your answer:9
# Correct answer!
#
#  Question2: 4 * 9
# your answer:35
# Wrong! The Correct Answer is: 36
#
#  Question3: 7 - 8
# your answer:6
# Wrong! The Correct Answer is: -1
#
#  Question4: 4 - 6
# your answer:6
# Wrong! The Correct Answer is: -2
#
#  Question5: 1 + 4
# your answer:5
# Correct answer!
#
# ---Game Over!---
# your final score is: 2/5
# Good job! You did well.
#
# ---Welcome to this Math quiz Game!
#
#  you will be presented a math problem and you need to provide correct answer.
#
#  Question1: 10 * 1
# your answer:10
# Correct answer!
#
#  Question2: 4 + 1
# your answer:5
# Correct answer!
#
#  Question3: 3 - 2
# your answer:1
# Correct answer!
#
#  Question4: 5 * 9
# your answer:8
# Wrong! The Correct Answer is: 45
#
#  Question5: 8 - 10
# your answer:2
# Wrong! The Correct Answer is: -2
#
# ---Game Over!---
# ...

# %% [markdown]
# ## Math Quiz Game: Practice Scenario for Students
#
# **Welcome, Mathematicians!**
#
# Get ready to challenge your brain with this fun 'Basic Math Quiz Game'. This game is designed to help you improve your mental math skills in addition, subtraction, and multiplication.
#
# **How to Play:**
#
# 1.  **Start the Game:** In your Colab notebook, find the code cell that calls `math_quiz()` (it might be at the bottom of the code). Run this cell.
# 2.  **Read the Question:** The game will present you with a math problem, like "7 + 3" or "5 * 4".
# 3.  **Enter Your Answer:** Type your answer into the box that appears and press **Enter**.
# 4.  **Get Feedback:** The game will immediately tell you if your answer was correct or incorrect. If you were wrong, it will show you the correct answer so you can learn from your mistakes!
# 5.  **Complete the Quiz:** You will answer 5 questions in total.
# 6.  **Review Your Score:** At the end of the 5 questions, the game will display your final score and give you a brief performance message.
#
# **Your Mission:**
#
# *   Try to answer as many questions correctly as possible!
# *   Don't be afraid to make mistakes; that's how we learn.
# *   You can run the `math_quiz()` cell multiple times to play again and get new questions. See if you can beat your previous score!
#
# **Why is this important?**
#
# Practicing basic math helps you think faster and solve more complex problems with ease. Enjoy the challenge!
